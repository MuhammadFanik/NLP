# %%
import nltk
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\muham\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\muham\AppData\Roaming\nltk_data...
# [nltk_data] Error downloading 'averaged_perceptron_tagger' from
# [nltk_data]     <https://raw.githubusercontent.com/nltk/nltk_data/gh-p
# [nltk_data]     ages/packages/taggers/averaged_perceptron_tagger.zip>:
# [nltk_data]     HTTP Error 503: Backend.max_conn reached
# False

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
words = ["running", "runs", "ran", "studies", "university", "better", "went"]

# %%
# Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(w) for w in words]

# %%
print(stemmed)
# Out:
# ['run', 'run', 'ran', 'studi', 'univers', 'better', 'went']

# %%
# Lemmatization - default
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(w) for w in words]

# %%
print(lemmatized)
# Out:
# ['running', 'run', 'ran', 'study', 'university', 'better', 'went']
