# %% [markdown]
# # Lowercasing

# %%
text = "The Quick BROWN Fox Jumps Over the LAZY Dog"

# %%
# Lowercasing
lowercase_text = text.lower()

print("Original Text:", text)
print("Lowercased Text:", lowercase_text)
# Out:
# Original Text: The Quick BROWN Fox Jumps Over the LAZY Dog
# Lowercased Text: the quick brown fox jumps over the lazy dog

# %% [markdown]
# ## Task

# %%
# Lowercase the entire string and print it.
text = "Breaking News: STOCK Prices Surge After the FEDERAL Reserve's Announcement!"

# %%
lowercase_string = text.lower()

# %%
print("Original Text:", text)
print("Lowercased text:", lowercase_string)
# Out:
# Original Text: Breaking News: STOCK Prices Surge After the FEDERAL Reserve's Announcement!
# Lowercased text: breaking news: stock prices surge after the federal reserve's announcement!
