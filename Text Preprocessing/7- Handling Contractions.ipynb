# %%
import contractions

# %%
text = "I don't think it's going to rain, but I can't be sure. She's already left."

# %%
expanded_text = contractions.fix(text)
print(expanded_text)
# Out:
# I do not think it is going to rain, but I cannot be sure. She is already left.

# %% [markdown]
# ### Task

# %%
text = "I'm not sure if they'll come, but we've already prepared everything. Won't you join us?"

# %%
expanded_text = contractions.fix(text)
print(expanded_text)
# Out:
# I am not sure if they will come, but we have already prepared everything. Will not you join us?
